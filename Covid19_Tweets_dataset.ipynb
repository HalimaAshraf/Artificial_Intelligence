# %% [markdown]
# <a href="https://colab.research.google.com/github/Usama55555/AI-Lab/blob/main/Covid19_Tweets_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/covid19_tweets.csv')
dataset
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
label = LabelEncoder()
label.fit(dataset.user_location.drop_duplicates())
dataset.user_location = label.transform(dataset.user_location)

label.fit(dataset.user_description.drop_duplicates())
dataset.user_description = label.transform(dataset.user_description)

label.fit(dataset.user_verified.drop_duplicates())
dataset.user_verified = label.transform(dataset.user_verified)

label.fit(dataset.text.drop_duplicates())
dataset.text = label.transform(dataset.text)

label.fit(dataset.user_created.drop_duplicates())
dataset.user_created = label.transform(dataset.user_created)

label.fit(dataset.date.drop_duplicates())
dataset.date = label.transform(dataset.date)

label.fit(dataset.hashtags.drop_duplicates())
dataset.hashtags = label.transform(dataset.hashtags)

label.fit(dataset.source.drop_duplicates())
dataset.source = label.transform(dataset.source)

label.fit(dataset.is_retweet.drop_duplicates())
dataset.is_retweet = label.transform(dataset.is_retweet)

dataset
# Out:
#         user_location  user_description  user_created  user_followers  \
# 0               24697             84799         66533             624
# 1               15312             34250          9144            2253
# 2               17090               866          6145            9275
# 3               20577               744         76075             197
# 4               10551             88876         65129          101009
# ...               ...               ...           ...             ...
# 179103           9918             10705         48654             412
# 179104          16381             78099         34778             150
# 179105          26717             86784         61910            1623
# 179106          15259             30900         16950            1338
# 179107           1563             67128         71213              97
#
#         user_friends  user_favourites  user_verified    date    text  \
# ...

# %%
from numpy.random.mtrand import RandomState
X_lin = dataset.drop(['user_favourites'], axis = 1)
Y_lin = dataset[['user_favourites']]


X_lin_train, X_lin_test, Y_lin_train, Y_lin_test = train_test_split(X_lin, Y_lin, test_size=0.3, random_state=42)

# %%
Linear_model = LinearRegression()
Linear_model.fit(X_lin_train, Y_lin_train)
# Out:
# LinearRegression()

# %%
pred = Linear_model.predict(X_lin_test)
pred
# Out:
# array([[ 7271.60964614],
#        [ 3432.82074067],
#        [12234.06711745],
#        ...,
#        [29055.14898289],
#        [16242.65686939],
#        [14835.580377  ]])

# %%
for idx, col_name in enumerate(X_lin_train.columns):
  print("The cofficient for {} is {}".format(col_name, Linear_model.coef_[0][idx]))
# Out:
# The cofficient for user_location is 0.09974478109287156
# The cofficient for user_description is -0.0251837801856839
# The cofficient for user_created is -0.1845024971185815
# The cofficient for user_followers is -0.0008195284794983229
# The cofficient for user_friends is 0.9297601082513642
# The cofficient for user_verified is -10355.954223739242
# The cofficient for date is -0.0001703390812306173
# The cofficient for text is -0.028130156784898934
# The cofficient for hashtags is -0.05212835186279163
# The cofficient for source is 37.8436054354474
# The cofficient for is_retweet is 0.0

# %%
intercept = Linear_model.intercept_[0]
intercept
# Out:
# 9452.776794634938
